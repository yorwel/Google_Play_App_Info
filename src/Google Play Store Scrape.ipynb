# %%
# To extract the following app details from Google Play Store

# name
# app_url
# appstore_url
# description
# operating_system
# application_category
# image
# content_rating
# author_name
# author_url
# rating_value
# rating_count
# price
# price_currency
# respective star rating (eg. 5star, 4star, 3star, 2star, 1 star)

# %%
# Import dependencies
import requests
import json
from bs4 import BeautifulSoup

# %%
# To convert "app search" url to "app info" url
def get_app_link(query):
	html_page = requests.get("https://play.google.com/store/search?q="+query+"&c=apps")
	soup = BeautifulSoup(html_page.text,'html.parser')
	applink = soup.find('a',attrs={'class':'Qfxief'})
	return applink['href']

# To extract relevant info from respecitve "app info" url
def get_app_info(app_name):
    base_url = 'https://play.google.com'
    app_url = base_url + get_app_link(app_name)
    
    data = requests.get(app_url)
    soup = BeautifulSoup(data.text, 'html.parser')

    # App information from info_boxes
    info_boxes = [json.loads(info_box.text.strip()) for info_box in soup.find_all('script', {'type': 'application/ld+json'})]

    # App rating (eg. 5star, 4star, 3star, 2star, 1 star)
    div_elements_with_class = soup.find_all('div', class_='RutFAf wcB8se')

    extracted_info = {}
    
    
    if info_boxes:
        
        info_box = info_boxes[0]  # Assuming you want information from the first box

        # Application Category and Subcategory
        application_category = info_box.get('applicationCategory', '')
        application_category_split = application_category.split('_')[0] if '_' in application_category else application_category
        application_subcategory_split = application_category.split('_')[1] if '_' in application_category else ""

        extracted_info = {
            'name': info_box.get('name', ''),
            'app_url' : app_url,
            'appstore_url': info_box.get('url', ''),
            'description': info_box.get('description', ''),
            'operating_system': info_box.get('operatingSystem', ''),
            'application_category': info_box.get('applicationCategory', ''),
            'application_category_split': application_category_split,
            'application_subcategory_split': application_subcategory_split,
            'image': info_box.get('image', ''),
            'content_rating': info_box.get('contentRating', ''),
            'author_name': info_box.get('author', {}).get('name', ''),
            'author_url': info_box.get('author', {}).get('url', ''),
            'rating_value': info_box.get('aggregateRating', {}).get('ratingValue', ''),
            'rating_count': info_box.get('aggregateRating', {}).get('ratingCount', ''),
            'price': info_box.get('offers', [{}])[0].get('price', ''),
            'price_currency': info_box.get('offers', [{}])[0].get('priceCurrency', '')
        }

    # div_elements_with_class = soup.find_all('div', class_='RutFAf wcB8se')
    star_ratings = []

    for i, div_element in enumerate(reversed(div_elements_with_class), 1):
        style_attribute = div_element.get('style', '')
        title_attribute = div_element.get('title', '')

        # Extracting width value from style attribute
        width_percentage = float(style_attribute.split(':')[1].replace('%', '').strip())

        # Extracting count from title attribute
        count = int(title_attribute.replace(',', '').strip())

        # Creating a dictionary with reversed star rating information
        star_dict = {'star_rating': i, 'percentage': width_percentage, 'count': count}
        star_ratings.append(star_dict)

    # Add star rating information to the extracted_info dictionary
    extracted_info['star_ratings'] = star_ratings

    return extracted_info

# %%
# query_list = ["whatsapp", "fairprice", "grab", "gpay", "honkai star rail", "genshin impact", "byd"]
query_list = ["call of duty", "minecraft", "clash of clan", "pokemon unite", "twinkle unicorn cat princess", "OCBC Digital"]

for query in query_list:
    app_info = get_app_info(query)
    print(f"App info for {query}:")
    print(app_info)
    print("\n")
# Out:
# App info for call of duty:
# {'name': 'Call of Duty: Mobile Season 2', 'app_url': 'https://play.google.com/store/apps/details?id=com.activision.callofduty.shooter', 'appstore_url': 'https://play.google.com/store/apps/details/Call_of_Duty_Mobile_Season_2?id=com.activision.callofduty.shooter&hl=en_US', 'description': 'Season 2 is out now! Survive and Dominate in Multiplayer FPS', 'operating_system': 'ANDROID', 'application_category': 'GAME_ACTION', 'application_category_split': 'GAME', 'application_subcategory_split': 'ACTION', 'image': 'https://play-lh.googleusercontent.com/zX7jmUbnCkH1LlhGFIffDv76OgJjIy3zZvzC6DPO-Cl-BPXfNVluTCDHTX6YSpvxKUrd', 'content_rating': 'Mature 17+', 'author_name': 'Activision Publishing, Inc.', 'author_url': 'http://www.activision.com', 'rating_value': '4.309465408325195', 'rating_count': '15905469', 'price': '0', 'price_currency': 'USD', 'star_ratings': [{'star_rating': 1, 'percentage': 10.650381402437201, 'count': 1639210}, {'star_rating': 2, 'percentage': 2.7316580266039603, 'count': 420432}, {'star_rating': 3, 'percentage': 4.410486273488587, 'count': 678822}, {'star_rating': 4, 'percentage': 8.72555371639647, 'count': 1342958}, {'star_rating': 5, 'percentage': 73.48184911116118, 'count': 11309659}]}
#
#
# App info for minecraft:
# {'name': 'Minecraft', 'app_url': 'https://play.google.com/store/apps/details?id=com.mojang.minecraftpe', 'appstore_url': 'https://play.google.com/store/apps/details/Minecraft?id=com.mojang.minecraftpe&hl=en_US', 'description': 'Millions of crafters have smashed billions of blocks! Now you can join the fun!', 'operating_system': 'ANDROID', 'application_category': 'GAME_ARCADE', 'application_category_split': 'GAME', 'application_subcategory_split': 'ARCADE', 'image': 'https://play-lh.googleusercontent.com/VSwHQjcAttxsLE47RuS4PqpC4LT7lCoSjE7Hx5AW_yCxtDvcnsHHvm5CTuL5BPN-uRTP', 'content_rating': 'Everyone 10+', 'author_name': 'Mojang', 'author_url': 'http://help.mojang.com', 'rating_value': '4.492412567138672', 'rating_count': '4975621', 'price': '6.99', 'price_currency': 'USD', 'star_ratings': [{'star_rating': 1, 'percentage': 7.060068851388694, 'count': 268390}, {'star_rating': 2, 'percentage': 2.189781405916211, 'count': 83245}, {'star_rating': 3, 'percentage': 4.024836374703704, 'count': 153005}, {'star_rating': 4, 'percentage': 8.552524108113568, 'count': 325126}, {'star_rating': 5, 'percentage': 78.1724999020129, 'count': 2971744}]}
#
#
# App info for clash of clan:
# {'name': 'Clash of Clans', 'app_url': 'https://play.google.com/store/apps/details?id=com.supercell.clashofclans', 'appstore_url': 'https://play.google.com/store/apps/details/Clash_of_Clans?id=com.supercell.clashofclans&hl=en_US', 'description': 'Epic combat strategy game. Build your village, train your troops & go to battle!', 'operating_system': 'ANDROID', 'application_category': 'GAME_STRATEGY', 'application_category_split': 'GAME', 'application_subcategory_split': 'STRATEGY', 'image': 'https://play-lh.googleusercontent.com/LByrur1mTmPeNr0ljI-uAUcct1rzmTve5Esau1SwoAzjBXQUby6uHIfHbF9TAT51mgHm', 'content_rating': 'Everyone 10+', 'author_name': 'Supercell', 'author_url': 'https://help.supercellsupport.com/clash-of-clans/en/', 'rating_value': '4.542494773864746', 'rating_count': '60898420', 'price': '0', 'price_currency': 'USD', 'star_ratings': [{'star_rating': 1, 'percentage': 6.15543620144375, 'count': 3388694}, {'star_rating': 2, 'percentage': 1.4732965544445726, 'count': 811080}, {'star_rating': 3, 'percentage': 3.4851797443412327, 'count': 1918663}, {'star_rating': 4, 'percentage': 10.282633782976268, 'count': 5660801}, {'star_rating': 5, 'percentage': 78.60340830522705, 'count': 43272790}]}
#
#
# App info for pokemon unite:
# {'name': 'Pokémon UNITE', 'app_url': 'https://play.google.com/store/apps/details?id=jp.pokemon.pokemonunite', 'appstore_url': 'https://play.google.com/store/apps/details/Pok%C3%A9mon_UNITE?id=jp.pokemon.pokemonunite&hl=en_US', 'description': '5-on-5 Strategic Team Pokémon Battles!', 'operating_system': 'ANDROID', 'application_category': 'GAME_ACTION', 'application_category_split': 'GAME', 'application_subcategory_split': 'ACTION', 'image': 'https://play-lh.googleusercontent.com/pLnno-Kti8gAEUfTTg_4StfrqyZ5Uj1uL-TfqhPsAjTQtNplljjJNgXImoRFtt8XLRw', 'content_rating': 'Everyone 10+', 'author_name': 'The Pokémon Company', 'author_url': '', 'rating_value': '4.393420219421387', 'rating_count': '1530790', 'price': '0', 'price_currency': 'USD', 'star_ratings': [{'star_rating': 1, 'percentage': 9.265818147230922, 'count': 131513}, {'star_rating': 2, 'percentage': 2.4281793938710736, 'count': 34464}, {'star_rating': 3, 'percentage': 4.03808825964272, 'count': 57314}, {'star_rating': 4, 'percentage': 10.00447392616965, 'count': 141997}, {'star_rating': 5, 'percentage': 74.26062205187641, 'count': 1054007}]}
#
#
# App info for twinkle unicorn cat princess:
# {'name': 'Twinkle - Unicorn Cat Princess', 'app_url': 'https://play.google.com/store/apps/details?id=com.cuteandtinybabygames.twinkleunicorncatprincess.free', 'appstore_url': 'https://play.google.com/store/apps/details/Twinkle_Unicorn_Cat_Princess?id=com.cuteandtinybabygames.twinkleunicorncatprincess.free&hl=en_US', 'description': 'Hatch a magic egg & care for a virtual rainbow kitten girl in her royal palace!', 'operating_system': 'ANDROID', 'application_category': 'GAME_EDUCATIONAL', 'application_category_split': 'GAME', 'application_subcategory_split': 'EDUCATIONAL', 'image': 'https://play-lh.googleusercontent.com/BeXgSue72TpeRXE0GHzC0n3UpYEDR86XHC7RnNkDXF6-vJmRhw0xkfHghnxkgHq4zA', 'content_rating': 'Everyone', 'author_name': 'TutoTOONS', 'author_url': 'http://www.zaidimustudija.lt', 'rating_value': '4.175257682800293', 'rating_count': '22408', 'price': '0', 'price_currency': 'USD', 'star_ratings': [{'star_rating': 1, 'percentage': 8.939899287162383, 'count': 1367}, {'star_rating': 2, 'percentage': 3.9958145314237132, 'count': 611}, {'star_rating': 3, 'percentage': 4.937544961088222, 'count': 755}, {'star_rating': 4, 'percentage': 9.999346020534956, 'count': 1529}, {'star_rating': 5, 'percentage': 71.99659930678176, 'count': 11009}]}
#
#
# App info for OCBC Digital:
# {'name': 'OCBC Digital - Mobile Banking', 'app_url': 'https://play.google.com/store/apps/details?id=com.ocbc.mobile', 'appstore_url': 'https://play.google.com/store/apps/details/OCBC_Digital_Mobile_Banking?id=com.ocbc.mobile&hl=en_US', 'description': 'Access mobile banking services easily through the OCBC Digital app.', 'operating_system': 'ANDROID', 'application_category': 'FINANCE', 'application_category_split': 'FINANCE', 'application_subcategory_split': '', 'image': 'https://play-lh.googleusercontent.com/Uxi8Xz_8DW2fDlFYkZ5z7HEfznsUJfJIyYmq0l2T86L_4Si8847lP4o0_51RWcBWdQ', 'content_rating': 'Everyone', 'author_name': 'Oversea-Chinese Banking Corporation Limited', 'author_url': 'http://www.ocbc.com/onlinebanking', 'rating_value': '4.110000133514404', 'rating_count': '85760', 'price': '0', 'price_currency': 'USD', 'star_ratings': [{'star_rating': 1, 'percentage': 15.974179251872727, 'count': 13264}, {'star_rating': 2, 'percentage': 5.962617722860515, 'count': 4951}, {'star_rating': 3, 'percentage': 1.9160825685863623, 'count': 1591}, {'star_rating': 4, 'percentage': 3.939350145723439, 'count': 3271}, {'star_rating': 5, 'percentage': 71.99099164197798, 'count': 59777}]}

# %%
import pandas as pd

# Create an empty list to store DataFrames
dfs = []

# Loop through each query in the list
for query in query_list:
    app_info = get_app_info(query)
    
    # Convert the app_info dictionary to a DataFrame and append it to the list
    df = pd.DataFrame([app_info], index=[query])
    dfs.append(df)

# Concatenate the list of DataFrames into a single DataFrame
result_df = pd.concat(dfs)
result_df.to_csv('Google Play App Store Scrape.csv')

# Print the DataFrame
print(result_df)
# Out:
#                                                         name  \
# call of duty                   Call of Duty: Mobile Season 2
# minecraft                                          Minecraft
# clash of clan                                 Clash of Clans
# pokemon unite                                  Pokémon UNITE
# twinkle unicorn cat princess  Twinkle - Unicorn Cat Princess
# OCBC Digital                   OCBC Digital - Mobile Banking
#
#                                                                         app_url  \
# call of duty                  https://play.google.com/store/apps/details?id=...
# minecraft                     https://play.google.com/store/apps/details?id=...
# clash of clan                 https://play.google.com/store/apps/details?id=...
# pokemon unite                 https://play.google.com/store/apps/details?id=...
# twinkle unicorn cat princess  https://play.google.com/store/apps/details?id=...
# OCBC Digital                  https://play.google.com/store/apps/details?id=...
#
#                                                                    appstore_url  \
# call of duty                  https://play.google.com/store/apps/details/Cal...
# minecraft                     https://play.google.com/store/apps/details/Min...
# clash of clan                 https://play.google.com/store/apps/details/Cla...
# pokemon unite                 https://play.google.com/store/apps/details/Pok...
# twinkle unicorn cat princess  https://play.google.com/store/apps/details/Twi...
# OCBC Digital                  https://play.google.com/store/apps/details/OCB...
#
#                                                                     description  \
# call of duty                  Season 2 is out now! Survive and Dominate in M...
# minecraft                     Millions of crafters have smashed billions of ...
# clash of clan                 Epic combat strategy game. Build your village,...
# pokemon unite                            5-on-5 Strategic Team Pokémon Battles!
# twinkle unicorn cat princess  Hatch a magic egg & care for a virtual rainbow...
# OCBC Digital                  Access mobile banking services easily through ...
#
#                              operating_system application_category  \
# call of duty                          ANDROID          GAME_ACTION
# minecraft                             ANDROID          GAME_ARCADE
# clash of clan                         ANDROID        GAME_STRATEGY
# pokemon unite                         ANDROID          GAME_ACTION
# twinkle unicorn cat princess          ANDROID     GAME_EDUCATIONAL
# OCBC Digital                          ANDROID              FINANCE
#
#                              application_category_split  \
# call of duty                                       GAME
# minecraft                                          GAME
# clash of clan                                      GAME
# pokemon unite                                      GAME
# twinkle unicorn cat princess                       GAME
# OCBC Digital                                    FINANCE
#
#                              application_subcategory_split  \
# call of duty                                        ACTION
# minecraft                                           ARCADE
# clash of clan                                     STRATEGY
# pokemon unite                                       ACTION
# twinkle unicorn cat princess                   EDUCATIONAL
# OCBC Digital
#
#                                                                           image  \
# call of duty                  https://play-lh.googleusercontent.com/zX7jmUbn...
# minecraft                     https://play-lh.googleusercontent.com/VSwHQjcA...
# clash of clan                 https://play-lh.googleusercontent.com/LByrur1m...
# pokemon unite                 https://play-lh.googleusercontent.com/pLnno-Kt...
# twinkle unicorn cat princess  https://play-lh.googleusercontent.com/BeXgSue7...
# OCBC Digital                  https://play-lh.googleusercontent.com/Uxi8Xz_8...
#
#                              content_rating  \
# call of duty                     Mature 17+
# minecraft                      Everyone 10+
# clash of clan                  Everyone 10+
# pokemon unite                  Everyone 10+
# twinkle unicorn cat princess       Everyone
# OCBC Digital                       Everyone
#
#                                                               author_name  \
# call of duty                                  Activision Publishing, Inc.
# minecraft                                                          Mojang
# clash of clan                                                   Supercell
# pokemon unite                                         The Pokémon Company
# twinkle unicorn cat princess                                    TutoTOONS
# OCBC Digital                  Oversea-Chinese Banking Corporation Limited
#
#                                                                      author_url  \
# call of duty                                          http://www.activision.com
# minecraft                                                http://help.mojang.com
# clash of clan                 https://help.supercellsupport.com/clash-of-cla...
# pokemon unite
# twinkle unicorn cat princess                       http://www.zaidimustudija.lt
# OCBC Digital                                  http://www.ocbc.com/onlinebanking
#
#                                    rating_value rating_count price  \
# call of duty                  4.309465408325195     15905463     0
# minecraft                     4.492412567138672      4975621  6.99
# clash of clan                 4.542494773864746     60898416     0
# pokemon unite                 4.393420219421387      1530789     0
# twinkle unicorn cat princess  4.175257682800293        22408     0
# OCBC Digital                  4.110000133514404        85760     0
#
#                              price_currency  \
# call of duty                            USD
# minecraft                               USD
# clash of clan                           USD
# pokemon unite                           USD
# twinkle unicorn cat princess            USD
# OCBC Digital                            USD
#
#                                                                    star_ratings
# call of duty                  [{'star_rating': 1, 'percentage': 10.650839671...
# minecraft                     [{'star_rating': 1, 'percentage': 7.0600688513...
# clash of clan                 [{'star_rating': 1, 'percentage': 6.1554369841...
# pokemon unite                 [{'star_rating': 1, 'percentage': 9.2658246755...
# twinkle unicorn cat princess  [{'star_rating': 1, 'percentage': 8.9398992871...
# OCBC Digital                  [{'star_rating': 1, 'percentage': 15.974179251...
